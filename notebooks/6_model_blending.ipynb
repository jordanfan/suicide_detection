# %%
import warnings 
warnings.filterwarnings("ignore")

import numpy as np
import pandas as pd
from sklearn.model_selection import train_test_split, cross_val_score, GridSearchCV, RepeatedStratifiedKFold
from sklearn.metrics import classification_report,confusion_matrix, accuracy_score, precision_score, recall_score
import lightgbm as lgb
import keras

import pickle
# Out:
# 2023-07-31 21:50:13.135143: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.

# %% [markdown]
# # Load in all predicted probabilities and labels

# %%
folder = "model_predicted_proba/"

with open(folder + "y_val.pkl", 'rb') as handle:
    y_val = pickle.load(handle)
with open(folder + "y_test.pkl", 'rb') as handle:
    y_test = pickle.load(handle)
with open(folder + "embedding_val_preds.pkl", 'rb') as handle:
    embedding_val = pickle.load(handle)
#    embedding_val = embedding_val.drop("CNN Embedding LGB Preds", axis = 1)
with open(folder + "embedding_test_preds.pkl", 'rb') as handle:
    embedding_test = pickle.load(handle)
#    embedding_test = embedding_test.drop("CNN Embedding LGB Preds", axis = 1)

sentiment_val = pd.read_csv(folder + "sentiment_probabilities_val.csv")["1"]
sentiment_test = pd.read_csv(folder + "sentiment_probabilities_test.csv")["1"]
tfidf_val = pd.read_csv(folder + "tfidf_probabilities_val.csv", header = None)[1]
tfidf_test = pd.read_csv(folder + "tfidf_probabilities_test.csv", header = None)[1]

# %%
embedding_val["Sentiment Preds"] = sentiment_val
embedding_val["TFIDF Preds"] = tfidf_val
embedding_test["Sentiment Preds"] = sentiment_test
embedding_test["TFIDF Preds"] = tfidf_test

# %%
val_proba = np.array(embedding_val)
val_proba_train, val_proba_validation, y_val_train, y_val_validation = train_test_split(
    val_proba, y_val, test_size=0.1, random_state=42)

test_proba = np.array(embedding_test)

# %% [markdown]
# # Model Blending via Boosting

# %% [markdown]
# Use boosted trees to blend model probabilities. The models will most likely have very similar outputs and we want to focus on improving upon the errors

# %%
#Set to large number, set early stopping rounds
n_estimators = [2000] 
#Smaller dataset, try reducing learning rate
learning_rate = [0.001, 0.01] 
#tree grows leaf wise instead of depth wise for lightgbm, focus on tuning num leaves
num_leaves = [5, 10, 15, 20, 50] 
#set number of entries needed in a leaf to prevent overfitting
min_child_samples = [10, 25, 50, 100] 
#could be redundancy in predictions since models can be similar, 
#set L1 regularization to drop out unnecessary features
reg_alpha = [0.1, 0.2, 0.3] 
early_stopping_rounds = [50]
random_state = [42]

param_grid = {"n_estimators": n_estimators,
              "learning_rate": learning_rate,
              "num_leaves": num_leaves,
              "min_child_samples": min_child_samples,
              "reg_alpha": reg_alpha,
              "early_stopping_round": early_stopping_rounds,
              "random_state": random_state}

# %%
lgb_model = lgb.LGBMClassifier(force_row_wise = True)
grid_search = GridSearchCV(estimator = lgb_model, 
                           param_grid = param_grid, 
                           cv = 5,
                           n_jobs = -1, 
                           verbose = 2, 
                           scoring = "f1") 
grid_search.fit(val_proba_train, y_val_train, eval_set = [(val_proba_validation, y_val_validation)], eval_metric = "logloss")
grid_search.best_params_
# Out:
# Fitting 5 folds for each of 120 candidates, totalling 600 fits
# [LightGBM] [Info] Number of positive: 16698, number of negative: 16720
# [LightGBM] [Info] Total Bins 2015
# [LightGBM] [Info] Number of data points in the train set: 33418, number of used features: 8
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.499671 -> initscore=-0.001317
# [LightGBM] [Info] Start training from score -0.001317
# Training until validation scores don't improve for 50 rounds
# Did not meet early stopping. Best iteration is:
# [2000]	valid_0's binary_logloss: 0.23409
# [CV] END early_stopping_round=50, learning_rate=0.001, min_child_samples=10, n_estimators=2000, num_leaves=5, random_state=42, reg_alpha=0.1; total time=  13.4s
# [LightGBM] [Info] Number of positive: 16698, number of negative: 16720
# [LightGBM] [Info] Total Bins 2015
# [LightGBM] [Info] Number of data points in the train set: 33418, number of used features: 8
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.499671 -> initscore=-0.001317
# [LightGBM] [Info] Start training from score -0.001317
# Training until validation scores don't improve for 50 rounds
# Did not meet early stopping. Best iteration is:
# [2000]	valid_0's binary_logloss: 0.234091
# [CV] END early_stopping_round=50, learning_rate=0.001, min_child_samples=10, n_estimators=2000, num_leaves=5, random_state=42, reg_alpha=0.2; total time=  13.8s
# [LightGBM] [Info] Number of positive: 16698, number of negative: 16720
# [LightGBM] [Info] Total Bins 2019
# [LightGBM] [Info] Number of data points in the train set: 33418, number of used features: 8
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.499671 -> initscore=-0.001317
# [LightGBM] [Info] Start training from score -0.001317
# Training until validation scores don't improve for 50 rounds
# Did not meet early stopping. Best iteration is:
# [2000]	valid_0's binary_logloss: 0.234074
# [CV] END early_stopping_round=50, learning_rate=0.001, min_child_samples=10, n_estimators=2000, num_leaves=5, random_state=42, reg_alpha=0.3; total time=  13.4s
# [LightGBM] [Info] Number of positive: 16698, number of negative: 16720
# [LightGBM] [Info] Total Bins 2015
# [LightGBM] [Info] Number of data points in the train set: 33418, number of used features: 8
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.499671 -> initscore=-0.001317
# [LightGBM] [Info] Start training from score -0.001317
# Training until validation scores don't improve for 50 rounds
# Did not meet early stopping. Best iteration is:
# [2000]	valid_0's binary_logloss: 0.229548
# [CV] END early_stopping_round=50, learning_rate=0.001, min_child_samples=10, n_estimators=2000, num_leaves=10, random_state=42, reg_alpha=0.1; total time=  16.1s
# [LightGBM] [Info] Number of positive: 16699, number of negative: 16720
# [LightGBM] [Info] Total Bins 2013
# [LightGBM] [Info] Number of data points in the train set: 33419, number of used features: 8
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.499686 -> initscore=-0.001257
# [LightGBM] [Info] Start training from score -0.001257
# Training until validation scores don't improve for 50 rounds
# Did not meet early stopping. Best iteration is:
# [2000]	valid_0's binary_logloss: 0.229754
# [CV] END early_stopping_round=50, learning_rate=0.001, min_child_samples=10, n_estimators=2000, num_leaves=10, random_state=42, reg_alpha=0.1; total time=  17.3s
# [LightGBM] [Info] Number of positive: 16699, number of negative: 16720
# [LightGBM] [Info] Total Bins 2018
# [LightGBM] [Info] Number of data points in the train set: 33419, number of used features: 8
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.499686 -> initscore=-0.001257
# [LightGBM] [Info] Start training from score -0.001257
# Training until validation scores don't improve for 50 rounds
# Did not meet early stopping. Best iteration is:
# [2000]	valid_0's binary_logloss: 0.229626
# [CV] END early_stopping_round=50, learning_rate=0.001, min_child_samples=10, n_estimators=2000, num_leaves=10, random_state=42, reg_alpha=0.2; total time=  17.2s
# [LightGBM] [Info] Number of positive: 16698, number of negative: 16720
# [LightGBM] [Info] Total Bins 2021
# [LightGBM] [Info] Number of data points in the train set: 33418, number of used features: 8
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.499671 -> initscore=-0.001317
# [LightGBM] [Info] Start training from score -0.001317
# Training until validation scores don't improve for 50 rounds
# Did not meet early stopping. Best iteration is:
# [2000]	valid_0's binary_logloss: 0.229645
# [CV] END early_stopping_round=50, learning_rate=0.001, min_child_samples=10, n_estimators=2000, num_leaves=10, random_state=42, reg_alpha=0.3; total time=  17.6s
# [LightGBM] [Info] Number of positive: 16698, number of negative: 16720
# [LightGBM] [Info] Total Bins 2019
# [LightGBM] [Info] Number of data points in the train set: 33418, number of used features: 8
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.499671 -> initscore=-0.001317
# [LightGBM] [Info] Start training from score -0.001317
# Training until validation scores don't improve for 50 rounds
# Did not meet early stopping. Best iteration is:
# [2000]	valid_0's binary_logloss: 0.22905
# [CV] END early_stopping_round=50, learning_rate=0.001, min_child_samples=10, n_estimators=2000, num_leaves=15, random_state=42, reg_alpha=0.1; total time=  19.1s
# [LightGBM] [Info] Number of positive: 16698, number of negative: 16720
# [LightGBM] [Info] Total Bins 2015
# [LightGBM] [Info] Number of data points in the train set: 33418, number of used features: 8
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.499671 -> initscore=-0.001317
# [LightGBM] [Info] Start training from score -0.001317
# Training until validation scores don't improve for 50 rounds
# Did not meet early stopping. Best iteration is:
# [2000]	valid_0's binary_logloss: 0.227964
# [CV] END early_stopping_round=50, learning_rate=0.001, min_child_samples=10, n_estimators=2000, num_leaves=15, random_state=42, reg_alpha=0.2; total time=  19.7s
# [LightGBM] [Info] Number of positive: 16699, number of negative: 16720
# [LightGBM] [Info] Total Bins 2013
# [LightGBM] [Info] Number of data points in the train set: 33419, number of used features: 8
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.499686 -> initscore=-0.001257
# [LightGBM] [Info] Start training from score -0.001257
# Training until validation scores don't improve for 50 rounds
# Did not meet early stopping. Best iteration is:
# [2000]	valid_0's binary_logloss: 0.228635
# [CV] END early_stopping_round=50, learning_rate=0.001, min_child_samples=10, n_estimators=2000, num_leaves=15, random_state=42, reg_alpha=0.2; total time=  20.3s
# [LightGBM] [Info] Number of positive: 16699, number of negative: 16720
# [LightGBM] [Info] Total Bins 2018
# [LightGBM] [Info] Number of data points in the train set: 33419, number of used features: 8
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.499686 -> initscore=-0.001257
# [LightGBM] [Info] Start training from score -0.001257
# Training until validation scores don't improve for 50 rounds
# Did not meet early stopping. Best iteration is:
# [2000]	valid_0's binary_logloss: 0.228552
# [CV] END early_stopping_round=50, learning_rate=0.001, min_child_samples=10, n_estimators=2000, num_leaves=15, random_state=42, reg_alpha=0.3; total time=  19.8s
# [LightGBM] [Info] Number of positive: 16698, number of negative: 16720
# [LightGBM] [Info] Total Bins 2021
# [LightGBM] [Info] Number of data points in the train set: 33418, number of used features: 8
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.499671 -> initscore=-0.001317
# [LightGBM] [Info] Start training from score -0.001317
# Training until validation scores don't improve for 50 rounds
# Did not meet early stopping. Best iteration is:
# [2000]	valid_0's binary_logloss: 0.228169
# [CV] END early_stopping_round=50, learning_rate=0.001, min_child_samples=10, n_estimators=2000, num_leaves=20, random_state=42, reg_alpha=0.1; total time=  22.1s
# [LightGBM] [Info] Number of positive: 16698, number of negative: 16720
# [LightGBM] [Info] Total Bins 2019
# [LightGBM] [Info] Number of data points in the train set: 33418, number of used features: 8
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.499671 -> initscore=-0.001317
# [LightGBM] [Info] Start training from score -0.001317
# Training until validation scores don't improve for 50 rounds
# Did not meet early stopping. Best iteration is:
# [2000]	valid_0's binary_logloss: 0.22863
# [CV] END early_stopping_round=50, learning_rate=0.001, min_child_samples=10, n_estimators=2000, num_leaves=20, random_state=42, reg_alpha=0.2; total time=  22.5s
# [LightGBM] [Info] Number of positive: 16698, number of negative: 16720
# [LightGBM] [Info] Total Bins 2015
# [LightGBM] [Info] Number of data points in the train set: 33418, number of used features: 8
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.499671 -> initscore=-0.001317
# [LightGBM] [Info] Start training from score -0.001317
# Training until validation scores don't improve for 50 rounds
# Did not meet early stopping. Best iteration is:
# [2000]	valid_0's binary_logloss: 0.227659
# [CV] END early_stopping_round=50, learning_rate=0.001, min_child_samples=10, n_estimators=2000, num_leaves=20, random_state=42, reg_alpha=0.3; total time=  25.1s
# [LightGBM] [Info] Number of positive: 16699, number of negative: 16720
# [LightGBM] [Info] Total Bins 2013
# [LightGBM] [Info] Number of data points in the train set: 33419, number of used features: 8
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.499686 -> initscore=-0.001257
# [LightGBM] [Info] Start training from score -0.001257
# Training until validation scores don't improve for 50 rounds
# Did not meet early stopping. Best iteration is:
# [2000]	valid_0's binary_logloss: 0.228231
# [CV] END early_stopping_round=50, learning_rate=0.001, min_child_samples=10, n_estimators=2000, num_leaves=20, random_state=42, reg_alpha=0.3; total time=  22.1s
# [LightGBM] [Info] Number of positive: 16699, number of negative: 16720
# [LightGBM] [Info] Total Bins 2018
# [LightGBM] [Info] Number of data points in the train set: 33419, number of used features: 8
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.499686 -> initscore=-0.001257
# [LightGBM] [Info] Start training from score -0.001257
# Training until validation scores don't improve for 50 rounds
# Did not meet early stopping. Best iteration is:
# [2000]	valid_0's binary_logloss: 0.227943
# [CV] END early_stopping_round=50, learning_rate=0.001, min_child_samples=10, n_estimators=2000, num_leaves=50, random_state=42, reg_alpha=0.1; total time=  34.0s
# [LightGBM] [Info] Number of positive: 16698, number of negative: 16720
# [LightGBM] [Info] Total Bins 2021
# [LightGBM] [Info] Number of data points in the train set: 33418, number of used features: 8
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.499671 -> initscore=-0.001317
# [LightGBM] [Info] Start training from score -0.001317
# Training until validation scores don't improve for 50 rounds
# Did not meet early stopping. Best iteration is:
# [2000]	valid_0's binary_logloss: 0.227477
# [CV] END early_stopping_round=50, learning_rate=0.001, min_child_samples=10, n_estimators=2000, num_leaves=50, random_state=42, reg_alpha=0.2; total time=  37.6s
# [LightGBM] [Info] Number of positive: 16698, number of negative: 16720
# [LightGBM] [Info] Total Bins 2019
# [LightGBM] [Info] Number of data points in the train set: 33418, number of used features: 8
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.499671 -> initscore=-0.001317
# [LightGBM] [Info] Start training from score -0.001317
# Training until validation scores don't improve for 50 rounds
# Did not meet early stopping. Best iteration is:
# [2000]	valid_0's binary_logloss: 0.227446
# [CV] END early_stopping_round=50, learning_rate=0.001, min_child_samples=10, n_estimators=2000, num_leaves=50, random_state=42, reg_alpha=0.3; total time=  34.4s
# [LightGBM] [Info] Number of positive: 16698, number of negative: 16720
# [LightGBM] [Info] Total Bins 2015
# [LightGBM] [Info] Number of data points in the train set: 33418, number of used features: 8
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.499671 -> initscore=-0.001317
# [LightGBM] [Info] Start training from score -0.001317
# Training until validation scores don't improve for 50 rounds
# Did not meet early stopping. Best iteration is:
# [2000]	valid_0's binary_logloss: 0.23409
# [CV] END early_stopping_round=50, learning_rate=0.001, min_child_samples=25, n_estimators=2000, num_leaves=5, random_state=42, reg_alpha=0.1; total time=  16.6s
# [LightGBM] [Info] Number of positive: 16698, number of negative: 16720
# [LightGBM] [Info] Total Bins 2019
# [LightGBM] [Info] Number of data points in the train set: 33418, number of used features: 8
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.499671 -> initscore=-0.001317
# [LightGBM] [Info] Start training from score -0.001317
# Training until validation scores don't improve for 50 rounds
# Did not meet early stopping. Best iteration is:
# [2000]	valid_0's binary_logloss: 0.234052
# [CV] END early_stopping_round=50, learning_rate=0.001, min_child_samples=25, n_estimators=2000, num_leaves=5, random_state=42, reg_alpha=0.1; total time=  18.3s
# [LightGBM] [Info] Number of positive: 16698, number of negative: 16720
# [LightGBM] [Info] Total Bins 2015
# [LightGBM] [Info] Number of data points in the train set: 33418, number of used features: 8
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.499671 -> initscore=-0.001317
# [LightGBM] [Info] Start training from score -0.001317
# Training until validation scores don't improve for 50 rounds
# Did not meet early stopping. Best iteration is:
# [2000]	valid_0's binary_logloss: 0.234091
# [CV] END early_stopping_round=50, learning_rate=0.001, min_child_samples=25, n_estimators=2000, num_leaves=5, random_state=42, reg_alpha=0.2; total time=  14.0s
# [LightGBM] [Info] Number of positive: 16699, number of negative: 16720
# [LightGBM] [Info] Total Bins 2013
# [LightGBM] [Info] Number of data points in the train set: 33419, number of used features: 8
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.499686 -> initscore=-0.001257
# [LightGBM] [Info] Start training from score -0.001257
# Training until validation scores don't improve for 50 rounds
# Did not meet early stopping. Best iteration is:
# [2000]	valid_0's binary_logloss: 0.234135
# [CV] END early_stopping_round=50, learning_rate=0.001, min_child_samples=25, n_estimators=2000, num_leaves=5, random_state=42, reg_alpha=0.2; total time=  13.9s
# [LightGBM] [Info] Number of positive: 16699, number of negative: 16720
# [LightGBM] [Info] Total Bins 2018
# [LightGBM] [Info] Number of data points in the train set: 33419, number of used features: 8
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.499686 -> initscore=-0.001257
# [LightGBM] [Info] Start training from score -0.001257
# Training until validation scores don't improve for 50 rounds
# Did not meet early stopping. Best iteration is:
# [2000]	valid_0's binary_logloss: 0.234151
# [CV] END early_stopping_round=50, learning_rate=0.001, min_child_samples=25, n_estimators=2000, num_leaves=5, random_state=42, reg_alpha=0.3; total time=  13.8s
# [LightGBM] [Info] Number of positive: 16698, number of negative: 16720
# [LightGBM] [Info] Total Bins 2021
# [LightGBM] [Info] Number of data points in the train set: 33418, number of used features: 8
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.499671 -> initscore=-0.001317
# [LightGBM] [Info] Start training from score -0.001317
# Training until validation scores don't improve for 50 rounds
# Did not meet early stopping. Best iteration is:
# [2000]	valid_0's binary_logloss: 0.229648
# [CV] END early_stopping_round=50, learning_rate=0.001, min_child_samples=25, n_estimators=2000, num_leaves=10, random_state=42, reg_alpha=0.1; total time=  17.0s
# [LightGBM] [Info] Number of positive: 16698, number of negative: 16720
# [LightGBM] [Info] Total Bins 2019
# [LightGBM] [Info] Number of data points in the train set: 33418, number of used features: 8
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.499671 -> initscore=-0.001317
# [LightGBM] [Info] Start training from score -0.001317
# Training until validation scores don't improve for 50 rounds
# Did not meet early stopping. Best iteration is:
# [2000]	valid_0's binary_logloss: 0.230111
# [CV] END early_stopping_round=50, learning_rate=0.001, min_child_samples=25, n_estimators=2000, num_leaves=10, random_state=42, reg_alpha=0.2; total time=  17.4s
# [LightGBM] [Info] Number of positive: 16698, number of negative: 16720
# [LightGBM] [Info] Total Bins 2015
# [LightGBM] [Info] Number of data points in the train set: 33418, number of used features: 8
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.499671 -> initscore=-0.001317
# [LightGBM] [Info] Start training from score -0.001317
# Training until validation scores don't improve for 50 rounds
# Did not meet early stopping. Best iteration is:
# [2000]	valid_0's binary_logloss: 0.22958
# [CV] END early_stopping_round=50, learning_rate=0.001, min_child_samples=25, n_estimators=2000, num_leaves=10, random_state=42, reg_alpha=0.3; total time=  17.5s
# [LightGBM] [Info] Number of positive: 16699, number of negative: 16720
# [LightGBM] [Info] Total Bins 2013
# [LightGBM] [Info] Number of data points in the train set: 33419, number of used features: 8
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.499686 -> initscore=-0.001257
# [LightGBM] [Info] Start training from score -0.001257
# Training until validation scores don't improve for 50 rounds
# Did not meet early stopping. Best iteration is:
# [2000]	valid_0's binary_logloss: 0.229773
# [CV] END early_stopping_round=50, learning_rate=0.001, min_child_samples=25, n_estimators=2000, num_leaves=10, random_state=42, reg_alpha=0.3; total time=  17.5s
# [LightGBM] [Info] Number of positive: 16699, number of negative: 16720
# [LightGBM] [Info] Total Bins 2018
# [LightGBM] [Info] Number of data points in the train set: 33419, number of used features: 8
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.499686 -> initscore=-0.001257
# [LightGBM] [Info] Start training from score -0.001257
# Training until validation scores don't improve for 50 rounds
# Did not meet early stopping. Best iteration is:
# [2000]	valid_0's binary_logloss: 0.228526
# [CV] END early_stopping_round=50, learning_rate=0.001, min_child_samples=25, n_estimators=2000, num_leaves=15, random_state=42, reg_alpha=0.1; total time=  20.1s
# [LightGBM] [Info] Number of positive: 16698, number of negative: 16720
# [LightGBM] [Info] Total Bins 2021
# [LightGBM] [Info] Number of data points in the train set: 33418, number of used features: 8
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.499671 -> initscore=-0.001317
# [LightGBM] [Info] Start training from score -0.001317
# Training until validation scores don't improve for 50 rounds
# Did not meet early stopping. Best iteration is:
# [2000]	valid_0's binary_logloss: 0.228661
# [CV] END early_stopping_round=50, learning_rate=0.001, min_child_samples=25, n_estimators=2000, num_leaves=15, random_state=42, reg_alpha=0.2; total time=  19.6s
# [LightGBM] [Info] Number of positive: 16698, number of negative: 16720
# [LightGBM] [Info] Total Bins 2019
# [LightGBM] [Info] Number of data points in the train set: 33418, number of used features: 8
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.499671 -> initscore=-0.001317
# [LightGBM] [Info] Start training from score -0.001317
# Training until validation scores don't improve for 50 rounds
# Did not meet early stopping. Best iteration is:
# [2000]	valid_0's binary_logloss: 0.22907
# [CV] END early_stopping_round=50, learning_rate=0.001, min_child_samples=25, n_estimators=2000, num_leaves=15, random_state=42, reg_alpha=0.3; total time=  19.6s
# [LightGBM] [Info] Number of positive: 16698, number of negative: 16720
# [LightGBM] [Info] Total Bins 2015
# [LightGBM] [Info] Number of data points in the train set: 33418, number of used features: 8
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.499671 -> initscore=-0.001317
# [LightGBM] [Info] Start training from score -0.001317
# Training until validation scores don't improve for 50 rounds
# Did not meet early stopping. Best iteration is:
# [2000]	valid_0's binary_logloss: 0.227442
# [CV] END early_stopping_round=50, learning_rate=0.001, min_child_samples=25, n_estimators=2000, num_leaves=20, random_state=42, reg_alpha=0.1; total time=  21.7s
# [LightGBM] [Info] Number of positive: 16699, number of negative: 16720
# [LightGBM] [Info] Total Bins 2013
# [LightGBM] [Info] Number of data points in the train set: 33419, number of used features: 8
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.499686 -> initscore=-0.001257
# [LightGBM] [Info] Start training from score -0.001257
# Training until validation scores don't improve for 50 rounds
# Did not meet early stopping. Best iteration is:
# [2000]	valid_0's binary_logloss: 0.228146
# [CV] END early_stopping_round=50, learning_rate=0.001, min_child_samples=25, n_estimators=2000, num_leaves=20, random_state=42, reg_alpha=0.1; total time=  21.7s
# [LightGBM] [Info] Number of positive: 16699, number of negative: 16720
# [LightGBM] [Info] Total Bins 2018
# [LightGBM] [Info] Number of data points in the train set: 33419, number of used features: 8
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.499686 -> initscore=-0.001257
# [LightGBM] [Info] Start training from score -0.001257
# Training until validation scores don't improve for 50 rounds
# Did not meet early stopping. Best iteration is:
# [2000]	valid_0's binary_logloss: 0.227927
# [CV] END early_stopping_round=50, learning_rate=0.001, min_child_samples=25, n_estimators=2000, num_leaves=20, random_state=42, reg_alpha=0.2; total time=  22.0s
# [LightGBM] [Info] Number of positive: 16698, number of negative: 16720
# [LightGBM] [Info] Total Bins 2021
# [LightGBM] [Info] Number of data points in the train set: 33418, number of used features: 8
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.499671 -> initscore=-0.001317
# [LightGBM] [Info] Start training from score -0.001317
# Training until validation scores don't improve for 50 rounds
# Did not meet early stopping. Best iteration is:
# [2000]	valid_0's binary_logloss: 0.2282
# [CV] END early_stopping_round=50, learning_rate=0.001, min_child_samples=25, n_estimators=2000, num_leaves=20, random_state=42, reg_alpha=0.3; total time=  22.5s
# [LightGBM] [Info] Number of positive: 16698, number of negative: 16720
# [LightGBM] [Info] Total Bins 2019
# [LightGBM] [Info] Number of data points in the train set: 33418, number of used features: 8
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.499671 -> initscore=-0.001317
# [LightGBM] [Info] Start training from score -0.001317
# Training until validation scores don't improve for 50 rounds
# Did not meet early stopping. Best iteration is:
# [2000]	valid_0's binary_logloss: 0.227208
# [CV] END early_stopping_round=50, learning_rate=0.001, min_child_samples=25, n_estimators=2000, num_leaves=50, random_state=42, reg_alpha=0.1; total time=  30.6s
# [LightGBM] [Info] Number of positive: 16698, number of negative: 16720
# [LightGBM] [Info] Total Bins 2015
# [LightGBM] [Info] Number of data points in the train set: 33418, number of used features: 8
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.499671 -> initscore=-0.001317
# [LightGBM] [Info] Start training from score -0.001317
# Training until validation scores don't improve for 50 rounds
# Did not meet early stopping. Best iteration is:
# [2000]	valid_0's binary_logloss: 0.226916
# [CV] END early_stopping_round=50, learning_rate=0.001, min_child_samples=25, n_estimators=2000, num_leaves=50, random_state=42, reg_alpha=0.2; total time=  32.5s
# [LightGBM] [Info] Number of positive: 16699, number of negative: 16720
# [LightGBM] [Info] Total Bins 2013
# [LightGBM] [Info] Number of data points in the train set: 33419, number of used features: 8
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.499686 -> initscore=-0.001257
# [LightGBM] [Info] Start training from score -0.001257
# Training until validation scores don't improve for 50 rounds
# Did not meet early stopping. Best iteration is:
# [2000]	valid_0's binary_logloss: 0.227461
# [CV] END early_stopping_round=50, learning_rate=0.001, min_child_samples=25, n_estimators=2000, num_leaves=50, random_state=42, reg_alpha=0.2; total time=  33.4s
# [LightGBM] [Info] Number of positive: 16699, number of negative: 16720
# [LightGBM] [Info] Total Bins 2018
# [LightGBM] [Info] Number of data points in the train set: 33419, number of used features: 8
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.499686 -> initscore=-0.001257
# [LightGBM] [Info] Start training from score -0.001257
# Training until validation scores don't improve for 50 rounds
# Did not meet early stopping. Best iteration is:
# [2000]	valid_0's binary_logloss: 0.228069
# [CV] END early_stopping_round=50, learning_rate=0.001, min_child_samples=25, n_estimators=2000, num_leaves=50, random_state=42, reg_alpha=0.3; total time=  31.1s
# [LightGBM] [Info] Number of positive: 16699, number of negative: 16720
# [LightGBM] [Info] Total Bins 2018
# [LightGBM] [Info] Number of data points in the train set: 33419, number of used features: 8
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.499686 -> initscore=-0.001257
# [LightGBM] [Info] Start training from score -0.001257
# Training until validation scores don't improve for 50 rounds
# Did not meet early stopping. Best iteration is:
# [2000]	valid_0's binary_logloss: 0.234132
# [CV] END early_stopping_round=50, learning_rate=0.001, min_child_samples=50, n_estimators=2000, num_leaves=5, random_state=42, reg_alpha=0.1; total time=  14.4s
# [LightGBM] [Info] Number of positive: 16698, number of negative: 16720
# [LightGBM] [Info] Total Bins 2021
# [LightGBM] [Info] Number of data points in the train set: 33418, number of used features: 8
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.499671 -> initscore=-0.001317
# [LightGBM] [Info] Start training from score -0.001317
# Training until validation scores don't improve for 50 rounds
# Did not meet early stopping. Best iteration is:
# [2000]	valid_0's binary_logloss: 0.234125
# [CV] END early_stopping_round=50, learning_rate=0.001, min_child_samples=50, n_estimators=2000, num_leaves=5, random_state=42, reg_alpha=0.2; total time=  15.3s
# [LightGBM] [Info] Number of positive: 16698, number of negative: 16720
# [LightGBM] [Info] Total Bins 2019
# [LightGBM] [Info] Number of data points in the train set: 33418, number of used features: 8
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.499671 -> initscore=-0.001317
# [LightGBM] [Info] Start training from score -0.001317
# Training until validation scores don't improve for 50 rounds
# Did not meet early stopping. Best iteration is:
# [2000]	valid_0's binary_logloss: 0.234074
# [CV] END early_stopping_round=50, learning_rate=0.001, min_child_samples=50, n_estimators=2000, num_leaves=5, random_state=42, reg_alpha=0.3; total time=  15.9s
# [LightGBM] [Info] Number of positive: 16698, number of negative: 16720
# [LightGBM] [Info] Total Bins 2015
# [LightGBM] [Info] Number of data points in the train set: 33418, number of used features: 8
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.499671 -> initscore=-0.001317
# [LightGBM] [Info] Start training from score -0.001317
# Training until validation scores don't improve for 50 rounds
# Did not meet early stopping. Best iteration is:
# [2000]	valid_0's binary_logloss: 0.229573
# [CV] END early_stopping_round=50, learning_rate=0.001, min_child_samples=50, n_estimators=2000, num_leaves=10, random_state=42, reg_alpha=0.1; total time=  19.0s
# [LightGBM] [Info] Number of positive: 16699, number of negative: 16720
# [LightGBM] [Info] Total Bins 2013
# [LightGBM] [Info] Number of data points in the train set: 33419, number of used features: 8
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.499686 -> initscore=-0.001257
# [LightGBM] [Info] Start training from score -0.001257
# Training until validation scores don't improve for 50 rounds
# Did not meet early stopping. Best iteration is:
# [2000]	valid_0's binary_logloss: 0.229771
# [CV] END early_stopping_round=50, learning_rate=0.001, min_child_samples=50, n_estimators=2000, num_leaves=10, random_state=42, reg_alpha=0.1; total time=  16.7s
# [LightGBM] [Info] Number of positive: 16699, number of negative: 16720
# [LightGBM] [Info] Total Bins 2018
# [LightGBM] [Info] Number of data points in the train set: 33419, number of used features: 8
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.499686 -> initscore=-0.001257
# [LightGBM] [Info] Start training from score -0.001257
# Training until validation scores don't improve for 50 rounds
# Did not meet early stopping. Best iteration is:
# [2000]	valid_0's binary_logloss: 0.229638
# [CV] END early_stopping_round=50, learning_rate=0.001, min_child_samples=50, n_estimators=2000, num_leaves=10, random_state=42, reg_alpha=0.2; total time=  17.6s
# [LightGBM] [Info] Number of positive: 16698, number of negative: 16720
# [LightGBM] [Info] Total Bins 2021
# [LightGBM] [Info] Number of data points in the train set: 33418, number of used features: 8
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.499671 -> initscore=-0.001317
# [LightGBM] [Info] Start training from score -0.001317
# Training until validation scores don't improve for 50 rounds
# Did not meet early stopping. Best iteration is:
# [2000]	valid_0's binary_logloss: 0.229668
# [CV] END early_stopping_round=50, learning_rate=0.001, min_child_samples=50, n_estimators=2000, num_leaves=10, random_state=42, reg_alpha=0.3; total time=  16.5s
# [LightGBM] [Info] Number of positive: 16698, number of negative: 16720
# [LightGBM] [Info] Total Bins 2019
# [LightGBM] [Info] Number of data points in the train set: 33418, number of used features: 8
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.499671 -> initscore=-0.001317
# [LightGBM] [Info] Start training from score -0.001317
# Training until validation scores don't improve for 50 rounds
# Did not meet early stopping. Best iteration is:
# [2000]	valid_0's binary_logloss: 0.229046
# [CV] END early_stopping_round=50, learning_rate=0.001, min_child_samples=50, n_estimators=2000, num_leaves=15, random_state=42, reg_alpha=0.1; total time=  19.4s
# [LightGBM] [Info] Number of positive: 16698, number of negative: 16720
# [LightGBM] [Info] Total Bins 2015
# [LightGBM] [Info] Number of data points in the train set: 33418, number of used features: 8
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.499671 -> initscore=-0.001317
# [LightGBM] [Info] Start training from score -0.001317
# Training until validation scores don't improve for 50 rounds
# Did not meet early stopping. Best iteration is:
# [2000]	valid_0's binary_logloss: 0.227955
# [CV] END early_stopping_round=50, learning_rate=0.001, min_child_samples=50, n_estimators=2000, num_leaves=15, random_state=42, reg_alpha=0.2; total time=  19.1s
# [LightGBM] [Info] Number of positive: 16699, number of negative: 16720
# [LightGBM] [Info] Total Bins 2013
# [LightGBM] [Info] Number of data points in the train set: 33419, number of used features: 8
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.499686 -> initscore=-0.001257
# [LightGBM] [Info] Start training from score -0.001257
# Training until validation scores don't improve for 50 rounds
# Did not meet early stopping. Best iteration is:
# [2000]	valid_0's binary_logloss: 0.228622
# [CV] END early_stopping_round=50, learning_rate=0.001, min_child_samples=50, n_estimators=2000, num_leaves=15, random_state=42, reg_alpha=0.2; total time=  19.4s
# [LightGBM] [Info] Number of positive: 16699, number of negative: 16720
# [LightGBM] [Info] Total Bins 2018
# [LightGBM] [Info] Number of data points in the train set: 33419, number of used features: 8
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.499686 -> initscore=-0.001257
# [LightGBM] [Info] Start training from score -0.001257
# Training until validation scores don't improve for 50 rounds
# Did not meet early stopping. Best iteration is:
# [2000]	valid_0's binary_logloss: 0.22852
# [CV] END early_stopping_round=50, learning_rate=0.001, min_child_samples=50, n_estimators=2000, num_leaves=15, random_state=42, reg_alpha=0.3; total time=  19.7s
# [LightGBM] [Info] Number of positive: 16698, number of negative: 16720
# [LightGBM] [Info] Total Bins 2021
# [LightGBM] [Info] Number of data points in the train set: 33418, number of used features: 8
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.499671 -> initscore=-0.001317
# [LightGBM] [Info] Start training from score -0.001317
# Training until validation scores don't improve for 50 rounds
# Did not meet early stopping. Best iteration is:
# [2000]	valid_0's binary_logloss: 0.228168
# [CV] END early_stopping_round=50, learning_rate=0.001, min_child_samples=50, n_estimators=2000, num_leaves=20, random_state=42, reg_alpha=0.1; total time=  21.7s
# [LightGBM] [Info] Number of positive: 16698, number of negative: 16720
# [LightGBM] [Info] Total Bins 2019
# [LightGBM] [Info] Number of data points in the train set: 33418, number of used features: 8
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.499671 -> initscore=-0.001317
# [LightGBM] [Info] Start training from score -0.001317
# Training until validation scores don't improve for 50 rounds
# Did not meet early stopping. Best iteration is:
# [2000]	valid_0's binary_logloss: 0.228453
# [CV] END early_stopping_round=50, learning_rate=0.001, min_child_samples=50, n_estimators=2000, num_leaves=20, random_state=42, reg_alpha=0.2; total time=  22.9s
# [LightGBM] [Info] Number of positive: 16698, number of negative: 16720
# [LightGBM] [Info] Total Bins 2015
# [LightGBM] [Info] Number of data points in the train set: 33418, number of used features: 8
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.499671 -> initscore=-0.001317
# [LightGBM] [Info] Start training from score -0.001317
# Training until validation scores don't improve for 50 rounds
# Did not meet early stopping. Best iteration is:
# [2000]	valid_0's binary_logloss: 0.227431
# [CV] END early_stopping_round=50, learning_rate=0.001, min_child_samples=50, n_estimators=2000, num_leaves=20, random_state=42, reg_alpha=0.3; total time=  20.9s
# [LightGBM] [Info] Number of positive: 16699, number of negative: 16720
# [LightGBM] [Info] Total Bins 2013
# [LightGBM] [Info] Number of data points in the train set: 33419, number of used features: 8
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.499686 -> initscore=-0.001257
# [LightGBM] [Info] Start training from score -0.001257
# Training until validation scores don't improve for 50 rounds
# Did not meet early stopping. Best iteration is:
# [2000]	valid_0's binary_logloss: 0.228095
# [CV] END early_stopping_round=50, learning_rate=0.001, min_child_samples=50, n_estimators=2000, num_leaves=20, random_state=42, reg_alpha=0.3; total time=  22.8s
# [LightGBM] [Info] Number of positive: 16699, number of negative: 16720
# [LightGBM] [Info] Total Bins 2018
# [LightGBM] [Info] Number of data points in the train set: 33419, number of used features: 8
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.499686 -> initscore=-0.001257
# [LightGBM] [Info] Start training from score -0.001257
# Training until validation scores don't improve for 50 rounds
# Did not meet early stopping. Best iteration is:
# [2000]	valid_0's binary_logloss: 0.227993
# [CV] END early_stopping_round=50, learning_rate=0.001, min_child_samples=50, n_estimators=2000, num_leaves=50, random_state=42, reg_alpha=0.1; total time=  32.1s
# [LightGBM] [Info] Number of positive: 16698, number of negative: 16720
# [LightGBM] [Info] Total Bins 2021
# [LightGBM] [Info] Number of data points in the train set: 33418, number of used features: 8
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.499671 -> initscore=-0.001317
# [LightGBM] [Info] Start training from score -0.001317
# Training until validation scores don't improve for 50 rounds
# Did not meet early stopping. Best iteration is:
# [2000]	valid_0's binary_logloss: 0.227188
# [CV] END early_stopping_round=50, learning_rate=0.001, min_child_samples=50, n_estimators=2000, num_leaves=50, random_state=42, reg_alpha=0.2; total time=  33.0s
# [LightGBM] [Info] Number of positive: 16698, number of negative: 16720
# [LightGBM] [Info] Total Bins 2019
# [LightGBM] [Info] Number of data points in the train set: 33418, number of used features: 8
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.499671 -> initscore=-0.001317
# [LightGBM] [Info] Start training from score -0.001317
# Training until validation scores don't improve for 50 rounds
# Did not meet early stopping. Best iteration is:
# [2000]	valid_0's binary_logloss: 0.226997
# [CV] END early_stopping_round=50, learning_rate=0.001, min_child_samples=50, n_estimators=2000, num_leaves=50, random_state=42, reg_alpha=0.3; total time=  40.1s
# [LightGBM] [Info] Number of positive: 16698, number of negative: 16720
# [LightGBM] [Info] Total Bins 2015
# [LightGBM] [Info] Number of data points in the train set: 33418, number of used features: 8
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.499671 -> initscore=-0.001317
# [LightGBM] [Info] Start training from score -0.001317
# Training until validation scores don't improve for 50 rounds
# Did not meet early stopping. Best iteration is:
# [2000]	valid_0's binary_logloss: 0.23409
# [CV] END early_stopping_round=50, learning_rate=0.001, min_child_samples=100, n_estimators=2000, num_leaves=5, random_state=42, reg_alpha=0.1; total time=  23.6s
# [LightGBM] [Info] Number of positive: 16699, number of negative: 16720
# [LightGBM] [Info] Total Bins 2018
# [LightGBM] [Info] Number of data points in the train set: 33419, number of used features: 8
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.499686 -> initscore=-0.001257
# [LightGBM] [Info] Start training from score -0.001257
# Training until validation scores don't improve for 50 rounds
# Did not meet early stopping. Best iteration is:
# [2000]	valid_0's binary_logloss: 0.234132
# [CV] END early_stopping_round=50, learning_rate=0.001, min_child_samples=100, n_estimators=2000, num_leaves=5, random_state=42, reg_alpha=0.1; total time=  19.2s
# [LightGBM] [Info] Number of positive: 16698, number of negative: 16720
# [LightGBM] [Info] Total Bins 2021
# [LightGBM] [Info] Number of data points in the train set: 33418, number of used features: 8
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.499671 -> initscore=-0.001317
# [LightGBM] [Info] Start training from score -0.001317
# Training until validation scores don't improve for 50 rounds
# Did not meet early stopping. Best iteration is:
# [2000]	valid_0's binary_logloss: 0.234125
# [CV] END early_stopping_round=50, learning_rate=0.001, min_child_samples=100, n_estimators=2000, num_leaves=5, random_state=42, reg_alpha=0.2; total time=  14.0s
# [LightGBM] [Info] Number of positive: 16698, number of negative: 16720
# [LightGBM] [Info] Total Bins 2019
# [LightGBM] [Info] Number of data points in the train set: 33418, number of used features: 8
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.499671 -> initscore=-0.001317
# [LightGBM] [Info] Start training from score -0.001317
# Training until validation scores don't improve for 50 rounds
# Did not meet early stopping. Best iteration is:
# [2000]	valid_0's binary_logloss: 0.234074
# [CV] END early_stopping_round=50, learning_rate=0.001, min_child_samples=100, n_estimators=2000, num_leaves=5, random_state=42, reg_alpha=0.3; total time=  13.7s
# [LightGBM] [Info] Number of positive: 16698, number of negative: 16720
# [LightGBM] [Info] Total Bins 2015
# [LightGBM] [Info] Number of data points in the train set: 33418, number of used features: 8
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.499671 -> initscore=-0.001317
# [LightGBM] [Info] Start training from score -0.001317
# Training until validation scores don't improve for 50 rounds
# Did not meet early stopping. Best iteration is:
# [2000]	valid_0's binary_logloss: 0.229567
# [CV] END early_stopping_round=50, learning_rate=0.001, min_child_samples=100, n_estimators=2000, num_leaves=10, random_state=42, reg_alpha=0.1; total time=  16.3s
# [LightGBM] [Info] Number of positive: 16699, number of negative: 16720
# [LightGBM] [Info] Total Bins 2013
# [LightGBM] [Info] Number of data points in the train set: 33419, number of used features: 8
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.499686 -> initscore=-0.001257
# [LightGBM] [Info] Start training from score -0.001257
# Training until validation scores don't improve for 50 rounds
# Did not meet early stopping. Best iteration is:
# [2000]	valid_0's binary_logloss: 0.229736
# [CV] END early_stopping_round=50, learning_rate=0.001, min_child_samples=100, n_estimators=2000, num_leaves=10, random_state=42, reg_alpha=0.1; total time=  17.9s
# [LightGBM] [Info] Number of positive: 16699, number of negative: 16720
# [LightGBM] [Info] Total Bins 2018
# [LightGBM] [Info] Number of data points in the train set: 33419, number of used features: 8
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.499686 -> initscore=-0.001257
# [LightGBM] [Info] Start training from score -0.001257
# Training until validation scores don't improve for 50 rounds
# Did not meet early stopping. Best iteration is:
# [2000]	valid_0's binary_logloss: 0.229674
# [CV] END early_stopping_round=50, learning_rate=0.001, min_child_samples=100, n_estimators=2000, num_leaves=10, random_state=42, reg_alpha=0.2; total time=  17.2s
# [LightGBM] [Info] Number of positive: 16698, number of negative: 16720
# [LightGBM] [Info] Total Bins 2021
# [LightGBM] [Info] Number of data points in the train set: 33418, number of used features: 8
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.499671 -> initscore=-0.001317
# [LightGBM] [Info] Start training from score -0.001317
# Training until validation scores don't improve for 50 rounds
# Did not meet early stopping. Best iteration is:
# [2000]	valid_0's binary_logloss: 0.229737
# [CV] END early_stopping_round=50, learning_rate=0.001, min_child_samples=100, n_estimators=2000, num_leaves=10, random_state=42, reg_alpha=0.3; total time=  19.2s
# [LightGBM] [Info] Number of positive: 16698, number of negative: 16720
# [LightGBM] [Info] Total Bins 2019
# [LightGBM] [Info] Number of data points in the train set: 33418, number of used features: 8
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.499671 -> initscore=-0.001317
# [LightGBM] [Info] Start training from score -0.001317
# Training until validation scores don't improve for 50 rounds
# Did not meet early stopping. Best iteration is:
# [2000]	valid_0's binary_logloss: 0.229087
# [CV] END early_stopping_round=50, learning_rate=0.001, min_child_samples=100, n_estimators=2000, num_leaves=15, random_state=42, reg_alpha=0.1; total time=  18.9s
# [LightGBM] [Info] Number of positive: 16698, number of negative: 16720
# [LightGBM] [Info] Total Bins 2015
# [LightGBM] [Info] Number of data points in the train set: 33418, number of used features: 8
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.499671 -> initscore=-0.001317
# [LightGBM] [Info] Start training from score -0.001317
# Training until validation scores don't improve for 50 rounds
# Did not meet early stopping. Best iteration is:
# [2000]	valid_0's binary_logloss: 0.227856
# [CV] END early_stopping_round=50, learning_rate=0.001, min_child_samples=100, n_estimators=2000, num_leaves=15, random_state=42, reg_alpha=0.2; total time=  20.2s
# [LightGBM] [Info] Number of positive: 16699, number of negative: 16720
# [LightGBM] [Info] Total Bins 2013
# [LightGBM] [Info] Number of data points in the train set: 33419, number of used features: 8
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.499686 -> initscore=-0.001257
# [LightGBM] [Info] Start training from score -0.001257
# Training until validation scores don't improve for 50 rounds
# Did not meet early stopping. Best iteration is:
# [2000]	valid_0's binary_logloss: 0.228491
# [CV] END early_stopping_round=50, learning_rate=0.001, min_child_samples=100, n_estimators=2000, num_leaves=15, random_state=42, reg_alpha=0.2; total time=  20.7s
# [LightGBM] [Info] Number of positive: 16699, number of negative: 16720
# [LightGBM] [Info] Total Bins 2018
# [LightGBM] [Info] Number of data points in the train set: 33419, number of used features: 8
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.499686 -> initscore=-0.001257
# [LightGBM] [Info] Start training from score -0.001257
# Training until validation scores don't improve for 50 rounds
# Did not meet early stopping. Best iteration is:
# [2000]	valid_0's binary_logloss: 0.228554
# [CV] END early_stopping_round=50, learning_rate=0.001, min_child_samples=100, n_estimators=2000, num_leaves=15, random_state=42, reg_alpha=0.3; total time=  20.0s
# [LightGBM] [Info] Number of positive: 16698, number of negative: 16720
# [LightGBM] [Info] Total Bins 2021
# [LightGBM] [Info] Number of data points in the train set: 33418, number of used features: 8
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.499671 -> initscore=-0.001317
# [LightGBM] [Info] Start training from score -0.001317
# Training until validation scores don't improve for 50 rounds
# Did not meet early stopping. Best iteration is:
# [2000]	valid_0's binary_logloss: 0.227934
# [CV] END early_stopping_round=50, learning_rate=0.001, min_child_samples=100, n_estimators=2000, num_leaves=20, random_state=42, reg_alpha=0.1; total time=  20.8s
# [LightGBM] [Info] Number of positive: 16698, number of negative: 16720
# [LightGBM] [Info] Total Bins 2019
# [LightGBM] [Info] Number of data points in the train set: 33418, number of used features: 8
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.499671 -> initscore=-0.001317
# [LightGBM] [Info] Start training from score -0.001317
# Training until validation scores don't improve for 50 rounds
# Did not meet early stopping. Best iteration is:
# [2000]	valid_0's binary_logloss: 0.228345
# [CV] END early_stopping_round=50, learning_rate=0.001, min_child_samples=100, n_estimators=2000, num_leaves=20, random_state=42, reg_alpha=0.2; total time=  22.0s
# [LightGBM] [Info] Number of positive: 16698, number of negative: 16720
# [LightGBM] [Info] Total Bins 2015
# [LightGBM] [Info] Number of data points in the train set: 33418, number of used features: 8
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.499671 -> initscore=-0.001317
# [LightGBM] [Info] Start training from score -0.001317
# Training until validation scores don't improve for 50 rounds
# Did not meet early stopping. Best iteration is:
# [2000]	valid_0's binary_logloss: 0.227262
# [CV] END early_stopping_round=50, learning_rate=0.001, min_child_samples=100, n_estimators=2000, num_leaves=20, random_state=42, reg_alpha=0.3; total time=  21.7s
# [LightGBM] [Info] Number of positive: 16699, number of negative: 16720
# [LightGBM] [Info] Total Bins 2013
# [LightGBM] [Info] Number of data points in the train set: 33419, number of used features: 8
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.499686 -> initscore=-0.001257
# [LightGBM] [Info] Start training from score -0.001257
# Training until validation scores don't improve for 50 rounds
# Did not meet early stopping. Best iteration is:
# [2000]	valid_0's binary_logloss: 0.228085
# [CV] END early_stopping_round=50, learning_rate=0.001, min_child_samples=100, n_estimators=2000, num_leaves=20, random_state=42, reg_alpha=0.3; total time=  22.2s
# [LightGBM] [Info] Number of positive: 16699, number of negative: 16720
# [LightGBM] [Info] Total Bins 2018
# [LightGBM] [Info] Number of data points in the train set: 33419, number of used features: 8
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.499686 -> initscore=-0.001257
# [LightGBM] [Info] Start training from score -0.001257
# Training until validation scores don't improve for 50 rounds
# Did not meet early stopping. Best iteration is:
# [2000]	valid_0's binary_logloss: 0.226947
# [CV] END early_stopping_round=50, learning_rate=0.001, min_child_samples=100, n_estimators=2000, num_leaves=50, random_state=42, reg_alpha=0.1; total time=  33.1s
# [LightGBM] [Info] Number of positive: 16698, number of negative: 16720
# [LightGBM] [Info] Total Bins 2021
# [LightGBM] [Info] Number of data points in the train set: 33418, number of used features: 8
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.499671 -> initscore=-0.001317
# [LightGBM] [Info] Start training from score -0.001317
# Training until validation scores don't improve for 50 rounds
# Did not meet early stopping. Best iteration is:
# [2000]	valid_0's binary_logloss: 0.227065
# [CV] END early_stopping_round=50, learning_rate=0.001, min_child_samples=100, n_estimators=2000, num_leaves=50, random_state=42, reg_alpha=0.2; total time=  32.5s
# [LightGBM] [Info] Number of positive: 16698, number of negative: 16720
# [LightGBM] [Info] Total Bins 2019
# [LightGBM] [Info] Number of data points in the train set: 33418, number of used features: 8
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.499671 -> initscore=-0.001317
# ...
# Early stopping, best iteration is:
# [822]	valid_0's binary_logloss: 0.194767
# [CV] END early_stopping_round=50, learning_rate=0.01, min_child_samples=10, n_estimators=2000, num_leaves=5, random_state=42, reg_alpha=0.3; total time=   6.2s
# [LightGBM] [Info] Number of positive: 16699, number of negative: 16720
# [LightGBM] [Info] Total Bins 2018
# [LightGBM] [Info] Number of data points in the train set: 33419, number of used features: 8
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.499686 -> initscore=-0.001257
# [LightGBM] [Info] Start training from score -0.001257
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [676]	valid_0's binary_logloss: 0.194143
# [CV] END early_stopping_round=50, learning_rate=0.01, min_child_samples=10, n_estimators=2000, num_leaves=10, random_state=42, reg_alpha=0.1; total time=   6.1s
# [LightGBM] [Info] Number of positive: 16698, number of negative: 16720
# [LightGBM] [Info] Total Bins 2021
# [LightGBM] [Info] Number of data points in the train set: 33418, number of used features: 8
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.499671 -> initscore=-0.001317
# [LightGBM] [Info] Start training from score -0.001317
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [636]	valid_0's binary_logloss: 0.194342
# [CV] END early_stopping_round=50, learning_rate=0.01, min_child_samples=10, n_estimators=2000, num_leaves=10, random_state=42, reg_alpha=0.2; total time=   5.7s
# [LightGBM] [Info] Number of positive: 16698, number of negative: 16720
# [LightGBM] [Info] Total Bins 2019
# [LightGBM] [Info] Number of data points in the train set: 33418, number of used features: 8
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.499671 -> initscore=-0.001317
# [LightGBM] [Info] Start training from score -0.001317
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [696]	valid_0's binary_logloss: 0.194118
# [CV] END early_stopping_round=50, learning_rate=0.01, min_child_samples=10, n_estimators=2000, num_leaves=10, random_state=42, reg_alpha=0.3; total time=   6.2s
# [LightGBM] [Info] Number of positive: 16698, number of negative: 16720
# [LightGBM] [Info] Total Bins 2015
# [LightGBM] [Info] Number of data points in the train set: 33418, number of used features: 8
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.499671 -> initscore=-0.001317
# [LightGBM] [Info] Start training from score -0.001317
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [629]	valid_0's binary_logloss: 0.193912
# [CV] END early_stopping_round=50, learning_rate=0.01, min_child_samples=10, n_estimators=2000, num_leaves=15, random_state=42, reg_alpha=0.1; total time=   6.3s
# [LightGBM] [Info] Number of positive: 16699, number of negative: 16720
# [LightGBM] [Info] Total Bins 2013
# [LightGBM] [Info] Number of data points in the train set: 33419, number of used features: 8
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.499686 -> initscore=-0.001257
# [LightGBM] [Info] Start training from score -0.001257
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [597]	valid_0's binary_logloss: 0.194675
# [CV] END early_stopping_round=50, learning_rate=0.01, min_child_samples=10, n_estimators=2000, num_leaves=15, random_state=42, reg_alpha=0.1; total time=   6.5s
# [LightGBM] [Info] Number of positive: 16699, number of negative: 16720
# [LightGBM] [Info] Total Bins 2018
# [LightGBM] [Info] Number of data points in the train set: 33419, number of used features: 8
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.499686 -> initscore=-0.001257
# [LightGBM] [Info] Start training from score -0.001257
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [585]	valid_0's binary_logloss: 0.1943
# [CV] END early_stopping_round=50, learning_rate=0.01, min_child_samples=10, n_estimators=2000, num_leaves=15, random_state=42, reg_alpha=0.2; total time=   5.9s
# [LightGBM] [Info] Number of positive: 16698, number of negative: 16720
# [LightGBM] [Info] Total Bins 2021
# [LightGBM] [Info] Number of data points in the train set: 33418, number of used features: 8
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.499671 -> initscore=-0.001317
# [LightGBM] [Info] Start training from score -0.001317
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [579]	valid_0's binary_logloss: 0.194385
# [CV] END early_stopping_round=50, learning_rate=0.01, min_child_samples=10, n_estimators=2000, num_leaves=15, random_state=42, reg_alpha=0.3; total time=   6.1s
# [LightGBM] [Info] Number of positive: 16698, number of negative: 16720
# [LightGBM] [Info] Total Bins 2019
# [LightGBM] [Info] Number of data points in the train set: 33418, number of used features: 8
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.499671 -> initscore=-0.001317
# [LightGBM] [Info] Start training from score -0.001317
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [605]	valid_0's binary_logloss: 0.195014
# [CV] END early_stopping_round=50, learning_rate=0.01, min_child_samples=10, n_estimators=2000, num_leaves=20, random_state=42, reg_alpha=0.1; total time=   7.0s
# [LightGBM] [Info] Number of positive: 16698, number of negative: 16720
# [LightGBM] [Info] Total Bins 2015
# [LightGBM] [Info] Number of data points in the train set: 33418, number of used features: 8
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.499671 -> initscore=-0.001317
# [LightGBM] [Info] Start training from score -0.001317
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [599]	valid_0's binary_logloss: 0.194133
# [CV] END early_stopping_round=50, learning_rate=0.01, min_child_samples=10, n_estimators=2000, num_leaves=20, random_state=42, reg_alpha=0.2; total time=   7.1s
# [LightGBM] [Info] Number of positive: 16699, number of negative: 16720
# [LightGBM] [Info] Total Bins 2013
# [LightGBM] [Info] Number of data points in the train set: 33419, number of used features: 8
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.499686 -> initscore=-0.001257
# [LightGBM] [Info] Start training from score -0.001257
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [586]	valid_0's binary_logloss: 0.195061
# [CV] END early_stopping_round=50, learning_rate=0.01, min_child_samples=10, n_estimators=2000, num_leaves=20, random_state=42, reg_alpha=0.2; total time=   6.6s
# [LightGBM] [Info] Number of positive: 16699, number of negative: 16720
# [LightGBM] [Info] Total Bins 2018
# [LightGBM] [Info] Number of data points in the train set: 33419, number of used features: 8
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.499686 -> initscore=-0.001257
# [LightGBM] [Info] Start training from score -0.001257
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [530]	valid_0's binary_logloss: 0.194508
# [CV] END early_stopping_round=50, learning_rate=0.01, min_child_samples=10, n_estimators=2000, num_leaves=20, random_state=42, reg_alpha=0.3; total time=   6.3s
# [LightGBM] [Info] Number of positive: 16698, number of negative: 16720
# [LightGBM] [Info] Total Bins 2021
# [LightGBM] [Info] Number of data points in the train set: 33418, number of used features: 8
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.499671 -> initscore=-0.001317
# [LightGBM] [Info] Start training from score -0.001317
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [626]	valid_0's binary_logloss: 0.195342
# [CV] END early_stopping_round=50, learning_rate=0.01, min_child_samples=10, n_estimators=2000, num_leaves=50, random_state=42, reg_alpha=0.1; total time=   9.9s
# [LightGBM] [Info] Number of positive: 16698, number of negative: 16720
# [LightGBM] [Info] Total Bins 2019
# [LightGBM] [Info] Number of data points in the train set: 33418, number of used features: 8
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.499671 -> initscore=-0.001317
# [LightGBM] [Info] Start training from score -0.001317
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [485]	valid_0's binary_logloss: 0.195445
# [CV] END early_stopping_round=50, learning_rate=0.01, min_child_samples=10, n_estimators=2000, num_leaves=50, random_state=42, reg_alpha=0.2; total time=   8.3s
# [LightGBM] [Info] Number of positive: 16698, number of negative: 16720
# [LightGBM] [Info] Total Bins 2015
# [LightGBM] [Info] Number of data points in the train set: 33418, number of used features: 8
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.499671 -> initscore=-0.001317
# [LightGBM] [Info] Start training from score -0.001317
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [519]	valid_0's binary_logloss: 0.194301
# [CV] END early_stopping_round=50, learning_rate=0.01, min_child_samples=10, n_estimators=2000, num_leaves=50, random_state=42, reg_alpha=0.3; total time=   8.2s
# [LightGBM] [Info] Number of positive: 16699, number of negative: 16720
# [LightGBM] [Info] Total Bins 2013
# [LightGBM] [Info] Number of data points in the train set: 33419, number of used features: 8
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.499686 -> initscore=-0.001257
# [LightGBM] [Info] Start training from score -0.001257
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [563]	valid_0's binary_logloss: 0.196287
# [CV] END early_stopping_round=50, learning_rate=0.01, min_child_samples=10, n_estimators=2000, num_leaves=50, random_state=42, reg_alpha=0.3; total time=   8.2s
# [LightGBM] [Info] Number of positive: 16699, number of negative: 16720
# [LightGBM] [Info] Total Bins 2018
# [LightGBM] [Info] Number of data points in the train set: 33419, number of used features: 8
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.499686 -> initscore=-0.001257
# [LightGBM] [Info] Start training from score -0.001257
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [1023]	valid_0's binary_logloss: 0.1948
# [CV] END early_stopping_round=50, learning_rate=0.01, min_child_samples=25, n_estimators=2000, num_leaves=5, random_state=42, reg_alpha=0.1; total time=   7.1s
# [LightGBM] [Info] Number of positive: 16699, number of negative: 16720
# [LightGBM] [Info] Total Bins 2018
# [LightGBM] [Info] Number of data points in the train set: 33419, number of used features: 8
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.499686 -> initscore=-0.001257
# [LightGBM] [Info] Start training from score -0.001257
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [1048]	valid_0's binary_logloss: 0.194776
# [CV] END early_stopping_round=50, learning_rate=0.01, min_child_samples=25, n_estimators=2000, num_leaves=5, random_state=42, reg_alpha=0.2; total time=   7.4s
# [LightGBM] [Info] Number of positive: 16699, number of negative: 16720
# [LightGBM] [Info] Total Bins 2018
# [LightGBM] [Info] Number of data points in the train set: 33419, number of used features: 8
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.499686 -> initscore=-0.001257
# [LightGBM] [Info] Start training from score -0.001257
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [939]	valid_0's binary_logloss: 0.19483
# [CV] END early_stopping_round=50, learning_rate=0.01, min_child_samples=25, n_estimators=2000, num_leaves=5, random_state=42, reg_alpha=0.3; total time=   6.5s
# [LightGBM] [Info] Number of positive: 16698, number of negative: 16720
# [LightGBM] [Info] Total Bins 2021
# [LightGBM] [Info] Number of data points in the train set: 33418, number of used features: 8
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.499671 -> initscore=-0.001317
# [LightGBM] [Info] Start training from score -0.001317
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [643]	valid_0's binary_logloss: 0.194417
# [CV] END early_stopping_round=50, learning_rate=0.01, min_child_samples=25, n_estimators=2000, num_leaves=10, random_state=42, reg_alpha=0.1; total time=   5.7s
# [LightGBM] [Info] Number of positive: 16698, number of negative: 16720
# [LightGBM] [Info] Total Bins 2019
# [LightGBM] [Info] Number of data points in the train set: 33418, number of used features: 8
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.499671 -> initscore=-0.001317
# [LightGBM] [Info] Start training from score -0.001317
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [806]	valid_0's binary_logloss: 0.193768
# [CV] END early_stopping_round=50, learning_rate=0.01, min_child_samples=25, n_estimators=2000, num_leaves=10, random_state=42, reg_alpha=0.2; total time=   7.3s
# [LightGBM] [Info] Number of positive: 16698, number of negative: 16720
# [LightGBM] [Info] Total Bins 2019
# [LightGBM] [Info] Number of data points in the train set: 33418, number of used features: 8
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.499671 -> initscore=-0.001317
# [LightGBM] [Info] Start training from score -0.001317
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [795]	valid_0's binary_logloss: 0.193941
# [CV] END early_stopping_round=50, learning_rate=0.01, min_child_samples=25, n_estimators=2000, num_leaves=10, random_state=42, reg_alpha=0.3; total time=   7.0s
# [LightGBM] [Info] Number of positive: 16698, number of negative: 16720
# [LightGBM] [Info] Total Bins 2015
# [LightGBM] [Info] Number of data points in the train set: 33418, number of used features: 8
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.499671 -> initscore=-0.001317
# [LightGBM] [Info] Start training from score -0.001317
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [620]	valid_0's binary_logloss: 0.193685
# [CV] END early_stopping_round=50, learning_rate=0.01, min_child_samples=25, n_estimators=2000, num_leaves=15, random_state=42, reg_alpha=0.1; total time=   6.1s
# [LightGBM] [Info] Number of positive: 16699, number of negative: 16720
# [LightGBM] [Info] Total Bins 2013
# [LightGBM] [Info] Number of data points in the train set: 33419, number of used features: 8
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.499686 -> initscore=-0.001257
# [LightGBM] [Info] Start training from score -0.001257
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [611]	valid_0's binary_logloss: 0.194447
# [CV] END early_stopping_round=50, learning_rate=0.01, min_child_samples=25, n_estimators=2000, num_leaves=15, random_state=42, reg_alpha=0.1; total time=   6.2s
# [LightGBM] [Info] Number of positive: 16699, number of negative: 16720
# [LightGBM] [Info] Total Bins 2018
# [LightGBM] [Info] Number of data points in the train set: 33419, number of used features: 8
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.499686 -> initscore=-0.001257
# [LightGBM] [Info] Start training from score -0.001257
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [585]	valid_0's binary_logloss: 0.194597
# [CV] END early_stopping_round=50, learning_rate=0.01, min_child_samples=25, n_estimators=2000, num_leaves=15, random_state=42, reg_alpha=0.2; total time=   6.0s
# [LightGBM] [Info] Number of positive: 20873, number of negative: 20900
# [LightGBM] [Info] Total Bins 2021
# [LightGBM] [Info] Number of data points in the train set: 41773, number of used features: 8
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.499677 -> initscore=-0.001293
# [LightGBM] [Info] Start training from score -0.001293
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [709]	valid_0's binary_logloss: 0.1941
# {'early_stopping_round': 50,
#  'learning_rate': 0.01,
#  'min_child_samples': 50,
#  'n_estimators': 2000,
#  'num_leaves': 10,
#  'random_state': 42,
#  'reg_alpha': 0.3}

# %% [markdown]
# n_estimators = [2000]
#
# learning_rate = [0.001, 0.01]
#
# num_leaves = [5, 10, 15, 20, 50]
#
# min_child_samples = [10, 25, 50, 100]
#
# reg_alpha = [0.1, 0.2, 0.3]

# %%
blended_model = grid_search.best_estimator_

# %%
with open('models_blended.pkl', 'wb') as handle:
    pickle.dump(blended_model, handle)

# %%
blended_test_preds = blended_model.predict(test_proba)

# %%
print(classification_report(y_test, blended_test_preds, digits = 3))
# Out:
#               precision    recall  f1-score   support
#
#            0      0.933     0.933     0.933     23248
#            1      0.932     0.933     0.932     23167
#
#     accuracy                          0.933     46415
#    macro avg      0.933     0.933     0.933     46415
# weighted avg      0.933     0.933     0.933     46415

# %%
for col, importance in zip(embedding_test.columns,blended_model.feature_importances_):
    print(col, "-", importance)
# Out:
# Word Embedding Preds - 568
# CNN Embedding Preds - 813
# Doc2Vec LR Preds - 500
# Doc2Vec NN Preds - 701
# Word Embedding LGB Preds - 677
# CNN Embedding LGB Preds - 1071
# Sentiment Preds - 438
# TFIDF Preds - 1613

# %% [markdown]
# The TF-IDF predictions was the most important for the blended model's predictions, followed by the models that used the word embeddings generated by the 1D CNN.
